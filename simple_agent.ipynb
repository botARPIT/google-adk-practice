# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import load_dotenv
load_dotenv()
try:
    google_api_key = os.getenv("GOOGLE_API_KEY")
    if google_api_key:
        print(google_api_key)
        print("API KEY FOUND")
    else: 
        print('API KEY NOT FOUND')
except Exception as e:
    print("Configuration Error")
# Out:
# AIzaSyDFXFAH9IUG5dNEhGFrsg7fL9Svdp_WaoY
# API KEY FOUND

# %%
# Importing Agent Devlopment Kit Components
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("Successfully imported the ADK Components")
# Out:
# Successfully imported the ADK Components

# %%
# Configuring retry options

retry_config=types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=3,
    http_status_codes=[429, 500, 503, 504]
)

# %%
# Defining the agent

root_agent = Agent(
    name="helpful_assistance" ,# Used to give a name to the agent
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="Simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use google search for current information or if you are unsure about something",
    tools=[google_search]
)

print("Finished setitng up the root agent")
# Out:
# Finished setitng up the root agent

# %%
# Runner is a central component in ADK that helps to bring agents to life
runner = InMemoryRunner(agent=root_agent)
print("Created the runner")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/arpit/devlopement/agentic-ai-google-kaggle/myvenv/lib/python3.9/site-packages/google/adk/agents", which implies app name "agents".
# Created the runner

# %%
response = await runner.run_debug(
    "What is the ADK from Google? And what languages does it support?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is the ADK from Google? And what languages does it support?
# helpful_assistance > Google's Agent Development Kit (ADK) is a flexible, modular, and open-source framework designed for developers to create, deploy, and orchestrate AI agents. It aims to make agent development more like traditional software development, offering fine-grained control over agent behavior, orchestration, and tool usage directly within the code. The ADK is model-agnostic, meaning it can work with various large language models (LLMs) beyond just Google's Gemini, and is also deployment-agnostic. It is built to be compatible with other frameworks and supports features like state management, callbacks, streaming, and structured input/output.
#
# The ADK supports the following programming languages:
# *   **Python**
# *   **Java**
# *   **Go**
#
# It also allows integration with other popular open-source frameworks like LangChain, LangGraph, AG2, and CrewAI.

# %%
response = await runner.run_debug( "What's the weather in Mumbai today?" )
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in Mumbai today?
# helpful_assistance > The weather in Mumbai today, Thursday, November 13, 2025, is sunny with a high of 88°F (31°C) and a low of 76°F (24°C). The humidity is around 41%, and it feels like 89°F (32°C). There is a 0% chance of rain.
#
# Later in the day, the temperature is expected to hover around 27-28°C. The wind speed is around 3.65 to 13.6 km/h. The sun is expected to rise around 6:44 AM and set around 6:00 PM. The air quality index (AQI) in Mumbai is currently moderate.
