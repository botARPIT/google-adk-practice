# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import load_dotenv
load_dotenv()
try:
    google_api_key = os.getenv("GOOGLE_API_KEY")
    if google_api_key:
        print(google_api_key)
        print("API KEY FOUND")
    else: 
        print('API KEY NOT FOUND')
except Exception as e:
    print("Configuration Error")
# Out:
# AIzaSyDFXFAH9IUG5dNEhGFrsg7fL9Svdp_WaoY
# API KEY FOUND

# %%
import ollama

# %%
# Importing Agent Devlopment Kit Components
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("Successfully imported the ADK Components")
# Out:
# /Users/arpit/devlopement/agentic-ai-google-kaggle/myvenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# /Users/arpit/devlopement/agentic-ai-google-kaggle/myvenv/lib/python3.9/site-packages/google/api_core/_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.6) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# MCP requires Python 3.10 or above. Please upgrade your Python version in order to use it.
# ...

# %%
# Configuring retry options

retry_config=types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=3,
    http_status_codes=[429, 500, 503, 504]
)

# %%
# Defining the agent

root_agent = Agent(
    name="helpful_assistance" ,# Used to give a name to the agent
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="Simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use google search for current information or if you are unsure about something",
    tools=[google_search]
)

print("Finished setitng up the root agent")
# Out:
# Finished setitng up the root agent

# %%
# Runner is a central component in ADK that helps to bring agents to life
runner = InMemoryRunner(agent=root_agent)
print("Created the runner")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/Users/arpit/devlopement/agentic-ai-google-kaggle/myvenv/lib/python3.9/site-packages/google/adk/agents", which implies app name "agents".
# Created the runner

# %%
response = await runner.run_debug(
    "What is the ADK from Google? And what languages does it support?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is the ADK from Google? And what languages does it support?
# helpful_assistance > The ADK (Agent Development Kit) from Google is a flexible, modular, and open-source framework designed to simplify the development, deployment, and orchestration of AI agents. It applies software development principles to AI agent creation, making it easier for developers to build complex agentic architectures that can range from simple tasks to intricate workflows. The ADK is model-agnostic and deployment-agnostic, meaning it can work with various AI models and be deployed in different environments, from local machines to cloud platforms like Vertex AI Agent Engine.
#
# The ADK currently supports the following programming languages:
# *   **Python**
# *   **Java**
# *   **Go**
#
# Google has indicated that support for more languages is coming soon.

# %%
response = await runner.run_debug( "What's the weather in Mumbai today?" )
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in Mumbai today?
# helpful_assistance > The weather in Mumbai today, Thursday, November 13, 2025, is sunny with clear skies. The temperature is expected to be around 31°C (88°F) during the day and can drop to around 23-24°C (73-75°F) at night. It will feel like 31°C (88°F) due to humidity levels, which are around 41-57%. The chance of rain is very low, around 0%. Wind speeds are expected to be moderate, around 3.65 to 13.6 km/h. The Air Quality Index (AQI) is moderate, with PM10 levels at 161. Sunrise is expected around 6:44 AM and sunset around 6:00 PM.
